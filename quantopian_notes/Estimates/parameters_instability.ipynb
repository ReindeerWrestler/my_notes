# %% [markdown]
# A parameter is anything that a model uses to constrain its predictions. Commonly, a parameter is a quantity that helps to describe a data set or a distribution. For example, the mean of a normal distribution is a parameter; in fact, we say that a normal distribution is parametrized by its mean and variance
#
# Similarly, the mean of a set of observations is an estimate of the parameter of the underlying distribution
#
# Applies to all other params
#
# # You Never Know, You Only Estimate
#
# When you take the mean of a data set, you do not know the mean. You have estimated the mean as best you can from the data you have. The estimate can be off. This is true of any parameter you estimate. To actually understand what is going on you need to determine how good your estimate is by looking at its stability/standard error/confidence intervals.
#
# # Instability of estimates
#
# Whenever we consider a set of observations, our calculation of a parameter can only be an estimate. It will change as we take more measurements or as time passes and we get new observations. We can quantify the uncertainty in our estimate by looking at how the parameter changes as we look at different subsets of the data. For instance, standard deviation describes how different the mean of a set is from the mean of each observation, that is, from each observation itself. In financial applications, data often comes in time series. In this case, we can estimate a parameter at different points in time; say, for the previous 30 days. By looking at how much this moving estimate fluctuates as we change our time window, we can compute the instability of the estimated parameter.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# First, let's take a look at some samples from a normal distribution. We know that the mean of the distribution is 0 and the standard deviation is 1; but if we measure the parameters from our observations, we will get only approximately 0 and approximately 1. We can see how these estimates change as we take more and more samples:

# %%
# Set a seed so we can play with the data without generating new random numbers every time
np.random.seed(123)

normal = np.random.randn(500)
print(np.mean(normal[:10]))
print(np.mean(normal[:100]))
print(np.mean(normal[:250]))
print(np.mean(normal))

# Plot a stacked histogram of the data
plt.hist([normal[:10], normal[10:100], normal[100:250], normal], normed=1, histtype='bar', stacked=True);
plt.ylabel('Frequency')
plt.xlabel('Value');
# Out:
# -0.26951611032632805
# 0.027109073490359778
# -0.020616059111720507
# -0.038643973513210604
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 11>()
#       8 print(np.mean(normal))
#      10 # Plot a stacked histogram of the data
# ---> 11 plt.hist([normal[:10], normal[10:100], normal[100:250], normal], normed=1, histtype='bar', stacked=True);
#      12 plt.ylabel('Frequency')
#      13 plt.xlabel('Value')
#
# File ~\anaconda3\envs\untitled\lib\site-packages\matplotlib\pyplot.py:2602, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2596 @_copy_docstring_and_deprecators(Axes.hist)
#    2597 def hist(
#    2598         x, bins=None, range=None, density=False, weights=None,
#    2599         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2600         orientation='vertical', rwidth=None, log=False, color=None,
#    2601         label=None, stacked=False, *, data=None, **kwargs):
# -> 2602     return gca().hist(
#    2603         x, bins=bins, range=range, density=density, weights=weights,
#    2604         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2605         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2606         color=color, label=label, stacked=stacked,
#    2607         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\envs\untitled\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\envs\untitled\lib\site-packages\matplotlib\axes\_axes.py:6787, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6785 if patch:
#    6786     p = patch[0]
# -> 6787     p.update(kwargs)
#    6788     if lbl is not None:
#    6789         p.set_label(lbl)
#
# File ~\anaconda3\envs\untitled\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
print(np.std(normal[:10]))
print(np.std(normal[:100]))
print(np.std(normal[:250]))
print(np.std(normal))
# Out:
# 1.236304801499023
# 1.128240470477961
# 1.0174604368340197
# 1.0032028561568238

# %% [markdown]
# Notice that, although the probability of getting closer to 0 and 1 for the mean and standard deviation, respectively, increases with the number of samples, we do not always get better estimates by taking more data points. Whatever our expectation is, we can always get a different result, and our goal is often to compute the probability that the result is significantly different than expected.
#
# With time series data, we usually care only about contiguous subsets of the data. The moving average (also called running or rolling) assigns the mean of the previous  data points to each point in time. Below, we compute the 90-day moving average of a stock price and plot it to see how it changes. There is no result in the beginning because we first have to accumulate at least 90 days of data.
#
# Example: Non-Normal Underlying Distribution
# What happens if the underlying data isn't normal? A mean will be very deceptive. Because of this it's important to test for normality of your data. We'll use a Jarque-Bera test as an example.

# %%
#Generate some data from a bi-modal distribution
def bimodal(n):
    X = np.zeros((n))
    for i in range(n):
        if np.random.binomial(1, 0.5) == 0:
            X[i] = np.random.normal(-5, 1)
        else:
            X[i] =  np.random.normal(5, 1)
    return X

X = bimodal(1000)

#Let's see how it looks
plt.hist(X, bins=50)
plt.ylabel('Frequency')
plt.xlabel('Value')
print('mean:', np.mean(X))
print('standard deviation:', np.std(X))
# Out:
# mean: 0.009847581282146528
# standard deviation: 5.060708740105227

# %% [markdown]
# Sure enough, the mean is incredibly non-informative about what is going on in the data. We have collapsed all of our data into a single estimate, and lost of a lot of information doing so. This is what the distribution should look like if our hypothesis that it is normally distributed is correct.

# %%
mu = np.mean(X)
sigma = np.std(X)

N = np.random.normal(mu, sigma, 1000)

plt.hist(N, bins=50)
plt.ylabel('Frequency')
plt.xlabel('Value');

# %% [markdown]
# We'll test our data using the Jarque-Bera test to see if it's normal. A significant p-value indicates non-normality.

# %%
from statsmodels.stats.stattools import jarque_bera

jarque_bera(X)
# Out:
# (142.12550136207705,
#  1.3735343038981241e-31,
#  -0.007644415681800414,
#  1.1531707484649847)

# %% [markdown]
# Sure enough the value is < 0.05 and we say that X is not normal. This saves us from accidentally making horrible predictions.
#
# Example: Sharpe ratio
# One statistic often used to describe the performance of assets and portfolios is the Sharpe ratio, which measures the additional return per unit additional risk achieved by a portfolio, relative to a risk-free source of return such as Treasury bills:

# %%
def sharpe_ratio(asset, riskfree):
    return np.mean(asset - riskfree)/np.std(asset - riskfree)

import pandas_datareader as pdr

# Use an ETF that tracks 3-month T-bills as our risk-free rate of return
data_tbill = pdr.get_data_yahoo('BIL')
data_aapl = pdr.get_data_yahoo('AAPL')
returns = data_aapl["Open"].pct_change()[1:]

running_sharpe = [sharpe_ratio(returns[i-90:i], data_tbill["Open"][i-90:i]) for i in range(90, len(returns))]

# Plot running Sharpe ratio up to 100 days before the end of the data set
_, ax1 = plt.subplots()
ax1.plot(range(90, len(returns)-100), running_sharpe[:-100]);
ticks = ax1.get_xticks()
ax1.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
plt.xlabel('Date')
plt.ylabel('Sharpe Ratio');
# Out:
# C:\Users\ncroc\AppData\Local\Temp\ipykernel_7308\843406347.py:17: FutureWarning: Indexing with a float is deprecated, and will raise an IndexError in pandas 2.0. You can manually convert to an integer key instead.
#   ax1.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
# C:\Users\ncroc\AppData\Local\Temp\ipykernel_7308\843406347.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates

# %% [markdown]
# The Sharpe ratio looks rather volatile, and it's clear that just reporting it as a single value will not be very helpful for predicting future values. Instead, we can compute the mean and standard deviation of the data above, and then see if it helps us predict the Sharpe ratio for the next 100 days.

# %%
# Compute the mean and std of the running Sharpe ratios up to 100 days before the end
mean_rs = np.mean(running_sharpe[:-100])
std_rs = np.std(running_sharpe[:-100])

# Plot running Sharpe ratio
_, ax2 = plt.subplots()
ax2.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
ax2.plot(range(90, len(returns)), running_sharpe)

# Plot its mean and the +/- 1 standard deviation lines
ax2.axhline(mean_rs)
ax2.axhline(mean_rs + std_rs, linestyle='--')
ax2.axhline(mean_rs - std_rs, linestyle='--')

# Indicate where we computed the mean and standard deviations
# Everything after this is 'out of sample' which we are comparing with the estimated mean and std
ax2.axvline(len(returns) - 100, color='pink');
plt.xlabel('Date')
plt.ylabel('Sharpe Ratio')
plt.legend(['Sharpe Ratio', 'Mean', '+/- 1 Standard Deviation'])

print('Mean of running Sharpe ratio:', mean_rs)
print('std of running Sharpe ratio:', std_rs)
# Out:
# Mean of running Sharpe ratio: -2872.800068443609
# std of running Sharpe ratio: 1303.5662121569858
# C:\Users\ncroc\AppData\Local\Temp\ipykernel_7308\3649042483.py:7: FutureWarning: Indexing with a float is deprecated, and will raise an IndexError in pandas 2.0. You can manually convert to an integer key instead.
#   ax2.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
# C:\Users\ncroc\AppData\Local\Temp\ipykernel_7308\3649042483.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates

# %% [markdown]
# Can also try with a moving average

# %%
# Compute the rolling mean for each day
mu = data_aapl["Open"].rolling(90).mean()

# Plot pricing data
_, ax1 = plt.subplots()
ax1.plot(data_aapl["Open"])
ticks = ax1.get_xticks()
ax1.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
plt.ylabel('Price')
plt.xlabel('Date')

# Plot rolling mean
ax1.plot(mu);
plt.legend(['Price','Rolling Average']);
# Out:
# C:\Users\ncroc\AppData\Local\Temp\ipykernel_7308\1693145760.py:8: FutureWarning: Indexing with a float is deprecated, and will raise an IndexError in pandas 2.0. You can manually convert to an integer key instead.
#   ax1.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [9], in <cell line: 8>()
#       6 ax1.plot(data_aapl["Open"])
#       7 ticks = ax1.get_xticks()
# ----> 8 ax1.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
#       9 plt.ylabel('Price')
#      10 plt.xlabel('Date')
#
# Input In [9], in <listcomp>(.0)
#       6 ax1.plot(data_aapl["Open"])
#       7 ticks = ax1.get_xticks()
# ----> 8 ax1.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
#       9 plt.ylabel('Price')
#      10 plt.xlabel('Date')
#
# File ~\anaconda3\envs\untitled\lib\site-packages\pandas\core\indexes\base.py:5039, in Index.__getitem__(self, key)
#    5036 if is_integer(key) or is_float(key):
#    5037     # GH#44051 exclude bool, which would return a 2d ndarray
#    5038     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5039     return getitem(key)
#    5041 if isinstance(key, slice):
#    5042     # This case is separated from the conditional above to avoid
#    5043     # pessimization com.is_bool_indexer and ndim checks.
#    5044     result = getitem(key)
#
# File ~\anaconda3\envs\untitled\lib\site-packages\pandas\core\arrays\datetimelike.py:341, in DatetimeLikeArrayMixin.__getitem__(self, key)
#     333 """
#     334 This getitem defers to the underlying array, which by-definition can
#     335 only handle list-likes, slices, and integer scalars
#     336 """
#     337 # Use cast as we know we will get back a DatetimeLikeArray or DTScalar,
#     338 # but skip evaluating the Union at runtime for performance
#     339 # (see https://github.com/pandas-dev/pandas/pull/44624)
#     340 result = cast(
# --> 341     "Union[DatetimeLikeArrayT, DTScalarOrNaT]", super().__getitem__(key)
#     342 )
#     343 if lib.is_scalar(result):
#     344     return result
#
# File ~\anaconda3\envs\untitled\lib\site-packages\pandas\core\arrays\_mixins.py:272, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     266 def __getitem__(
#     267     self: NDArrayBackedExtensionArrayT,
#     268     key: PositionalIndexer2D,
#     269 ) -> NDArrayBackedExtensionArrayT | Any:
#     270     if lib.is_integer(key):
#     271         # fast-path
# --> 272         result = self._ndarray[key]
#     273         if self.ndim == 1:
#     274             return self._box_func(result)
#
# IndexError: index 17167 is out of bounds for axis 0 with size 1259

# %%
# instability/standard error of the mean
print('Mean of rolling mean:', np.mean(mu))
print('std of rolling mean:', np.std(mu))
# Out:
# Mean of rolling mean: 91.12422666055186
# std of rolling mean: 44.840372733409524

# %%
# Compute rolling standard deviation
std = data_aapl["Open"].rolling(90).std()

# Plot rolling std
_, ax2 = plt.subplots()
ax2.plot(std)
ax2.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
plt.ylabel('Standard Deviation of Moving Average')
plt.xlabel('Date')

print('Mean of rolling std:', np.mean(std))
print('std of rolling std:', np.std(std))
# Out:
# C:\Users\ncroc\AppData\Local\Temp\ipykernel_7308\3349262858.py:7: FutureWarning: Indexing with a float is deprecated, and will raise an IndexError in pandas 2.0. You can manually convert to an integer key instead.
#   ax2.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [12], in <cell line: 7>()
#       5 _, ax2 = plt.subplots()
#       6 ax2.plot(std)
# ----> 7 ax2.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
#       8 plt.ylabel('Standard Deviation of Moving Average')
#       9 plt.xlabel('Date')
#
# Input In [12], in <listcomp>(.0)
#       5 _, ax2 = plt.subplots()
#       6 ax2.plot(std)
# ----> 7 ax2.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
#       8 plt.ylabel('Standard Deviation of Moving Average')
#       9 plt.xlabel('Date')
#
# File ~\anaconda3\envs\untitled\lib\site-packages\pandas\core\indexes\base.py:5039, in Index.__getitem__(self, key)
#    5036 if is_integer(key) or is_float(key):
#    5037     # GH#44051 exclude bool, which would return a 2d ndarray
#    5038     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5039     return getitem(key)
#    5041 if isinstance(key, slice):
#    5042     # This case is separated from the conditional above to avoid
#    5043     # pessimization com.is_bool_indexer and ndim checks.
#    5044     result = getitem(key)
#
# File ~\anaconda3\envs\untitled\lib\site-packages\pandas\core\arrays\datetimelike.py:341, in DatetimeLikeArrayMixin.__getitem__(self, key)
#     333 """
#     334 This getitem defers to the underlying array, which by-definition can
#     335 only handle list-likes, slices, and integer scalars
#     336 """
#     337 # Use cast as we know we will get back a DatetimeLikeArray or DTScalar,
#     338 # but skip evaluating the Union at runtime for performance
#     339 # (see https://github.com/pandas-dev/pandas/pull/44624)
#     340 result = cast(
# --> 341     "Union[DatetimeLikeArrayT, DTScalarOrNaT]", super().__getitem__(key)
#     342 )
#     343 if lib.is_scalar(result):
#     344     return result
#
# File ~\anaconda3\envs\untitled\lib\site-packages\pandas\core\arrays\_mixins.py:272, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     266 def __getitem__(
#     267     self: NDArrayBackedExtensionArrayT,
#     268     key: PositionalIndexer2D,
#     269 ) -> NDArrayBackedExtensionArrayT | Any:
#     270     if lib.is_integer(key):
#     271         # fast-path
# --> 272         result = self._ndarray[key]
#     273         if self.ndim == 1:
#     274             return self._box_func(result)
#
# IndexError: index 17167 is out of bounds for axis 0 with size 1259

# %%
# data with bollinger bands

# Plot original data
_, ax3 = plt.subplots()
ax3.plot(data_aapl["Open"])
ax3.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates

# Plot Bollinger bands
ax3.plot(mu)
ax3.plot(mu + std)
ax3.plot(mu - std);
plt.ylabel('Price')
plt.xlabel('Date')
plt.legend(['Price', 'Moving Average', 'Moving Average +1 Std', 'Moving Average -1 Std'])
# Out:
# C:\Users\ncroc\AppData\Local\Temp\ipykernel_7308\646340304.py:6: FutureWarning: Indexing with a float is deprecated, and will raise an IndexError in pandas 2.0. You can manually convert to an integer key instead.
#   ax3.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [13], in <cell line: 6>()
#       4 _, ax3 = plt.subplots()
#       5 ax3.plot(data_aapl["Open"])
# ----> 6 ax3.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
#       8 # Plot Bollinger bands
#       9 ax3.plot(mu)
#
# Input In [13], in <listcomp>(.0)
#       4 _, ax3 = plt.subplots()
#       5 ax3.plot(data_aapl["Open"])
# ----> 6 ax3.set_xticklabels([data_aapl["Open"].index[i].date() for i in ticks[:-1]]) # Label x-axis with dates
#       8 # Plot Bollinger bands
#       9 ax3.plot(mu)
#
# File ~\anaconda3\envs\untitled\lib\site-packages\pandas\core\indexes\base.py:5039, in Index.__getitem__(self, key)
#    5036 if is_integer(key) or is_float(key):
#    5037     # GH#44051 exclude bool, which would return a 2d ndarray
#    5038     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5039     return getitem(key)
#    5041 if isinstance(key, slice):
#    5042     # This case is separated from the conditional above to avoid
#    5043     # pessimization com.is_bool_indexer and ndim checks.
#    5044     result = getitem(key)
#
# File ~\anaconda3\envs\untitled\lib\site-packages\pandas\core\arrays\datetimelike.py:341, in DatetimeLikeArrayMixin.__getitem__(self, key)
#     333 """
#     334 This getitem defers to the underlying array, which by-definition can
#     335 only handle list-likes, slices, and integer scalars
#     336 """
#     337 # Use cast as we know we will get back a DatetimeLikeArray or DTScalar,
#     338 # but skip evaluating the Union at runtime for performance
#     339 # (see https://github.com/pandas-dev/pandas/pull/44624)
#     340 result = cast(
# --> 341     "Union[DatetimeLikeArrayT, DTScalarOrNaT]", super().__getitem__(key)
#     342 )
#     343 if lib.is_scalar(result):
#     344     return result
#
# File ~\anaconda3\envs\untitled\lib\site-packages\pandas\core\arrays\_mixins.py:272, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     266 def __getitem__(
#     267     self: NDArrayBackedExtensionArrayT,
#     268     key: PositionalIndexer2D,
#     269 ) -> NDArrayBackedExtensionArrayT | Any:
#     270     if lib.is_integer(key):
#     271         # fast-path
# --> 272         result = self._ndarray[key]
#     273         if self.ndim == 1:
#     274             return self._box_func(result)
#
# IndexError: index 17167 is out of bounds for axis 0 with size 1259
